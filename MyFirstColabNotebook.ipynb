# %%
import time
print(time.ctime())
# Out:
# Mon Mar 10 16:44:59 2025

# %%
time.sleep(5)
print(time.ctime())
# Out:
# Mon Mar 10 16:45:04 2025

# %% [markdown]
# This is **bold**.
# This is *itallix*.
# This is ~strikethrough~.

# %% [markdown]
# $\sqrt{3x+1}+(1+x)^2$

# %% [markdown]
# $e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$
